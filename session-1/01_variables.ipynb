# %% [markdown]
# *Variables y tipos*

# %%
#  Escribe una variable pública y otra privada según el convenio seguido en Python. Imprime ambos resultados por pantalla.

# Private variable
_name = "David Ballesteros"

# Public variable
nickname = "DavidNickName"
