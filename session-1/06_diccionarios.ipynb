# %% [markdown]
# **Diccionarios**

# %%
# TODO write some variables holding dictionaries, both empty and populated

rhaneyra_dragons = {"Rhanerya": "Syrax", "Lucerys": "Vermax", "Adam": "Seasmoke", "Jacerys": "Stormcloud"}
aegon_dragons = {"Aemond": "Vhagar", "Daemon": "Caraxes", "Rhaenyra": "Syrax"}
got_dragons =  {}

print(f"Dictionary rhaneyra_dragons: {rhaneyra_dragons}")
print(f"Dictionary aegon_dragons: {aegon_dragons}")

# Add few elements to the empty dictionary
got_dragons = {"Danerys": "Drogon", "Jon" :"Rhaegal",  "NightKing":"Viserion"}
print(f"Dictionary got_dragons: {got_dragons}")

# Access one of the elements of the dictionary by its key
adam_dragon = rhaneyra_dragons["Adam"]
print(f"Accesing the dragon of dictionary rhaneyra_dragons: {adam_dragon}")

# Update an element of the list
print(f"Dictionary rhaneyra_dragons before update: {rhaneyra_dragons["Jacerys"]}")
rhaneyra_dragons["Jacerys"] = "Vermax"
print(f"Dictionary rhaneyra_dragons after update: {rhaneyra_dragons["Jacerys"]}")

# Remove all the entries of the dictionary
got_dragons.clear()

# Check if the empty dictionary is in fact empty (by returning a boolean)
is_got_dragons_empty = len(got_dragons) == 0
print(f"Is the dictionary got_dragons empty? {is_got_dragons_empty}")

# Check if this key is in the populated dictionary: "world"
is_on_dictionary = "world" in rhaneyra_dragons
print(f"Is in the dictionary rhaneyra_dragons the key 'world'? {is_on_dictionary}")

# Try to get this element of the dictionary, if fails return "not found": "hello"
got_dragons.get("hello", "not found")
# Out:
# Dictionary rhaneyra_dragons: {'Rhanerya': 'Syrax', 'Lucerys': 'Vermax', 'Adam': 'Seasmoke', 'Jacerys': 'Stormcloud'}
# Dictionary aegon_dragons: {'Aemond': 'Vhagar', 'Daemon': 'Caraxes', 'Rhaenyra': 'Syrax'}
# Dictionary got_dragons: {'Danerys': 'Drogon', 'Jon': 'Rhaegal', 'NightKing': 'Viserion'}
# Accesing the dragon of dictionary rhaneyra_dragons: Seasmoke
# Dictionary rhaneyra_dragons before update: Stormcloud
# Dictionary rhaneyra_dragons after update: Vermax
# Is the dictionary got_dragons empty? True
# Is in the dictionary rhaneyra_dragons the key 'world'? False
# 'not found'
