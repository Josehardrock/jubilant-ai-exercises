# %% [markdown]
# **Hello World**

# %%
[ ] # Escribe un script que asigne a una variable tu nombre para mostrarla en pantalla con una frase

name = "David Ballesteros"
print(f"Hello, my name is {name}")
# Out:
# Hello, my name is David Ballesteros
