# %% [markdown]
# **Listas**

# %%
house_dragons = ["Vermax", "SilverFire", "Vermitor", "Syrax"]
got_dragons = ["Drogon", "Rhaegal", "Viserion"]
empty_dragons = []

#Add to emtpy list
empty_dragons.append("Sunfyre")
empty_dragons.append("Caraxes")

# Check if empty
is_empty = len(empty_dragons) == 0
print(f"Check Empty, {is_empty}")

# Get Sublist
sublist_dragons = house_dragons[2:3]
concatenated_list = empty_dragons + got_dragons
print(f"Concatenated List {concatenated_list}")

# Contains checks
print(f"Contains 1 is : {1 in concatenated_list}")
print(f"Contains Hello is : {"hello" in concatenated_list}")
print(f"Contains world is : {"world" in concatenated_list}")

# Empty list current
print(f"Empty list is now {empty_dragons}")
      
origin_list = [0, 1, 2, 3,"hello", "world"]
target_list = ["test", 0, 4, 5, 1, 2 , 3, "hello", "world"]

final_list = []

for item in origin_list:
    if item in target_list:
        final_list.append(item)

print(f"Final List is {final_list}")
# Out:
# Check Empty, False
# Concatenated List ['Sunfyre', 'Caraxes', 'Drogon', 'Rhaegal', 'Viserion']
# Contains 1 is : False
# Contains Hello is : False
# Contains world is : False
# Empty list is now ['Sunfyre', 'Caraxes']
# Final List is [0, 1, 2, 3, 'hello', 'world']
