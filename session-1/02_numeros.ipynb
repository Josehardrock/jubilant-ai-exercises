# %% [markdown]
# **Numeros**

# %%
# Escribe algunas variables con enteros, con coma flotante y complejos. Convierte los números con coma flotante y complejos en entero e imprime por pantalla.
# Integer, Float and Complex

int_number= 50
float_number = 50.5
complex_number = 9.322e-36j

float_to_int = int(float_number)

# Comples must use real property otherwise an exception is thrown
convertible_complex = complex_number.real
complex_to_int = int(convertible_complex)

print(f"Float to int is {float_to_int}")
print(f"Complex to int {complex_to_int}")
