# %% [markdown]
# # ¿Cuál es la diferencia entre las siguientes asignaciones de listas?
# # original_list = [1, 2, 3, 4]
# # new_list = original_list
# #  new_list_2 = original_list[:]
# # 	Recorre todos los elementos de original_list e imprime su índice y su valor

# %%
# Explica la diferencia (a nivel físico) entre pasar un parámetro por valor y por referencia. 

# Al pasar un parámetro por valor, se crea una copia del "contenido" que se le pasa al parámetro. 
# Al pasar por referencia, se entrega la dirección física del "contenido". 


# ¿Cuál es la diferencia entre las siguientes asignaciones de listas?
# original_list = [1, 2, 3, 4]

original_list = [1, 2, 3, 4]
#Crea  una nueva lista con los elementos 1,2,3,4

new_list = original_list
#Crea una referencia a la lista original_list

new_list_2 = original_list[:]
#Crea una lista nueva con los elementos del indice 0 hasta el ultimo de la lista original_list

print(f"original_list: {original_list}")

for item in original_list:
    print(f"Item index is {original_list.index(item)}, Item value is: {item}")
# Out:
# original_list: [1, 2, 3, 4]
# Item with index 0, value: 1
# Item with index 1, value: 2
# Item with index 2, value: 3
# Item with index 3, value: 4
