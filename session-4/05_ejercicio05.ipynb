# %% [markdown]
# Ejercicio 5
# •	Escribe un fragmento de código que intente dividir dos números y maneje la excepción que se produce cuando el denominador es cero.________________________________________
