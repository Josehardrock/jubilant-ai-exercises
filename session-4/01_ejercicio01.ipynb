# %%
# Ejercicio 1
# Utiliza NumPy para crear dos vectores de datos y luego crea un DataFrame en Pandas que utilice estos dos vectores como columnas. 
# # Finalmente, muestra las primeras cinco filas del DataFrame.


import numpy as np
import pandas as pd

planet_names = np.array(["Mercure", "Venus", "Mars", "Earth", "Jupyter", "Saturn", "Uranus", "Neptune"])
planet_position = np.array(["First", "Second", "Third", "Fourth", "Fifth", "Sixth", "Seventh", "Eighth"])

framed_vector = pd.DataFrame(data=planet_names, index=planet_position, columns=["Position PlanetNames"])

print(framed_vector[:5])
# Out:
#        Position PlanetNames
# First               Mercure
# Second                Venus
# Third                  Mars
# Fourth                Earth
# Fifth               Jupyter
